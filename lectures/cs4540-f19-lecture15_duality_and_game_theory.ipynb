# %% [markdown]
# $\LaTeX \text{ commands here}
# \newcommand{\R}{\mathbb{R}}
# \newcommand{\im}{\text{im}\,}
# \newcommand{\norm}[1]{||#1||}
# \newcommand{\inner}[1]{\langle #1 \rangle}
# \newcommand{\span}{\mathrm{span}}
# \newcommand{\proj}{\mathrm{proj}}
# \newcommand{\OPT}{\mathrm{OPT}}
# $

# %% [markdown]
# <hr style="border: 5px solid black">
#
# **Georgia Tech, CS 4540**
#
# # L8: Duality & Game Theory
#
# Jake Abernethy & Benjamin Bray
#
# *Tuesday, October 22, 2019*

# %% [markdown]
# ## Midterm results
#
# ![](images/midterm_f19_distribution.png)
#
# Roughly speaking:
# + $\geq 48/60$ is an A;
# + $\geq 34/60$ is a B

# %% [markdown]
# ### Recall:  Linear Program in Standard Form
#
# <div style="padding:20px;margin:20px;border: 1px solid black">
# \begin{align}
# \max_{x \in \R^n} &\quad c^T x \\
# \text{such that}  &\quad Ax \leq b & \text{(only $\leq$ constraints)} \\
#                   &\quad  x \geq 0 & \text{(variables nonnegative)}
# \end{align}
# </div>
#
# * Decision variables $x \in \R^n$
# * Linear objective $c^T x$ for $c \in \R^n$
# * Constraint matrix $A \in \R^{m \times n}$ and vector $b \in \R^m$.  Each row corresponds to a constraint.

# %% [markdown]
# ### Recall:  Activity Analysis Problem
#
# A company has $m$ different resources which can be used to manufacture $n$ different products.
#
# * $x = (x_1,\dots,x_n) \in \R^n$ is the amount of each product manufactured
# * $r = (r_1,\dots,r_m) \in \R^m$ is the supply of each resource
# * $c = (c_1,\dots,c_n) \in \R^n$ is the profit generated by each product
# * $A = [a_{ij}] \in \R^{m \times n}$, where $a_{ij}$ is the amount of resource $i$ needed to make product $j$
#
# <div style="padding:10px;margin:20px;border: 1px solid black">
# $$\max_{x \in \R^n} \quad c^T x \quad
# \text{s.t.} \quad A x \leq r \quad\text{and}\quad x \geq 0$$
# </div>

# %% [markdown]
# ### Problem:  Interpreting the Dual
#
# <div style="padding:20px;margin:20px;border: 1px solid black">
# <b>Problem:</b>  Write down the dual linear program for the activity analysis problem.  What "units" do the dual variables need have?  How can they be interpreted?
# </div>
#
# > If it helps, assume the amount of each resource available is measured in *kilograms*, and our profit is measured in *euros* €.  Maybe we're manufacturing rope, so the amount of each product is measured in *meters*.

# %% [markdown]
# ### Solution:  Interpreting the Dual (1)
#
# Using our rope factory example,
#
# * $r_i$ is measured in $(kg)$
# * $x_j$ is measured in $(m)$
# * $c_j$ is measured in $(€/m)$
# * $a_{ij}$ is measured in $(kg/m)$

# %% [markdown]
# ### Solution:  Interpreting the Dual (2)
#
# The dual program has the constraint $y^T A \geq c$, which has terms like $y_i a_{ij} \geq c_j$.  The units are
#
# $$
# \bigg( ? \bigg) \times \bigg( \frac{kg}{m} \bigg) \geq \bigg( \frac{€}{m} \bigg)
# $$
#
# * For this to make sense, $y_i$ needs to have units $(€/kg)$ or **euros per kilogram**.
# * Then the dual objective $y^T r$ has units $(€/kg)\times (kg) = (€)$.

# %% [markdown]
# ### Solution:  Interpreting the Dual (3)
#
# We decided that $y_i$ has units $(€/kg)$, and $y^T r$ has units $(€)$.
# * Imagine that we also have the option of **selling our resources** directly to a buyer, for a price of $y_i$ euros per kilogram, rather than turning them into rope.
# * This is only worth it to us if the resources used to make each rope are **more valuable** than the ropes themselves.  This is the dual constraint!
# * The buyer knows this, so he'll try to **minimize the amount he pays for our raw materials** by choosing as small $y_i$ as possible.
#
# <div style="padding:20px;margin:20px;border: 1px solid black">
# $$
# \begin{align}
# \min_{y \in \R^m} &\quad y^T r \\
# \text{such that}  &\quad y^T A \geq c^T & \text{(dominates objective)} \\
#                   &\quad  y \geq 0 & \text{(nonnegative combinations)}
# \end{align}
# $$
# </div>

# %% [markdown]
# #### Problem: Farkas Lemma (v2) implies Strong Duality
#
# <b>Lemma.</b> (Farkas)  Let $M \in \R^{m \times n}$ and $d \in \R^m$.  Then exactly one of the following two statements is true:
# 1.  There exists $x \in \R^n$ such that $Mx \geq d$ and $x \geq 0$.
# 2.  There exists $v \in \R^m$ such that $v^T M \leq 0$ and $d^T v > 0$ and $v \geq 0$
#
# **Prove** that strong duality holds using the Farkas Lemma (v2). That is, the following two are *equal*:
#
# $$
# \begin{align}
# \max_{x \in \R^n} &\quad c^T x & \text{such that}  &\quad A x \leq b, \quad x \geq 0 \\
# = \min_{y \in \R^m} &\quad y^T b & \text{such that}  &\quad y^T A \geq c^T, \quad y \geq 0 \\
# \end{align}
# $$

# %% [markdown]
# **Partial solution**: Assume towards a contradiction that it is NOT true. Let $x_0$ and $y_0$ be the optimal primal and dual solutions, but $c^T x_0 < y_0^T b$. Then we know the following set of constraints is **not** feasible:
# $$A x \leq b \quad \text{ and } \quad c^T x \geq b^T y_0 \quad \text{ and } \quad x \geq 0$$
# Now, apply the Farkas Lemma (v2) and finish the proof! (*Hint*: Need to pick $M, d$ carefully!)

# %% [markdown]
# ## Game Theory Basics
#
# * Much of economics is based on the idea that agents act independently of each other; that is, they don't coordinate their decisions
# * At the same time, the outcome of agents' actions depend on other agents actions too
# * How should I choose my actions to optimize my payoff, when all of the other agents are doing the same thing?
# * Understanding agents' behavior in such settings is the core goal of **game theory**

# %% [markdown]
# ![](images/history_game_theory.png)

# %% [markdown]
# ## The Prisonners' Dilemma
#
# * Imagine two friends are arrested for committing a crime. Whether they committed the crime is irrelevant!
# * The police offices put each of them in a room, and tell them they can CONFESS or DENY, and they tell them what will happen in all scenarios:
#     + If you both DENY, we will get you on an unrelated traffic violation and you both will get 1 year in prison
#     + If you CONFESS and your friend DENIES, you get to go home and your friend gets 10 years in prison. The same will happen to your friend in the reverse case.
#     + If you both CONFESS we will put you away for 8 years in prison
#
# What should each friend do here?

# %% [markdown]
# ## Zero-sum Games vs Non-zero-sum Games
#
# * The Prisonners' Dilemma is what we call a non-zero-sum game, since the costs/payouts don't sum to 0 (or some constant $c$)
# * We know that "solving" non-zero-sum games is *hard* in a certain sense (PPAD-hard to be exact -- [you can look this up here](https://people.csail.mit.edu/costis/simplified.pdf) if you want more information!)
# * But solving zero-sum games is not so hard! *Homework problem*: you will show that finding an equilibrium in a zero-sum game is solving a primal and dual linear program

# %% [markdown]
# ## Zero-sum game equilibrium
#
# Assume we have a zero-sum game matrix $M \in \R^{n \times m}$, where $M_{ij}$ is the loss to the row player (Player A) and the gain to the column player (Player B)
# ![](images/fzz8R.png)
#
# A pair of *mixed strategies* (i.e. distributions) $p \in \Delta_n$ and $q \in \Delta_m$ are an *equilibrium* of the game if for every $i \in [n], j \in [m]$ we have
# $$\sum_{k=1}^n p_k M_{kj} \leq \sum_{l = 1}^m q_l M_{i l}$$

# %% [markdown]
# ## The Minimax Theorem
#
# Proved by von Neumann in the 1920s!
#
# **Theorem**: For any matrix $M \in \R^{n \times m}$ we have
# $$\min_{p \in \Delta_n} \max_{j \in [m]} p^\top M_{:j} = \max_{q \in \Delta_m} \min_{i \in [n]} M_{i:} q$$
# Equivalently:
# $$\min_{p \in \Delta_n} \max_{q \in \Delta_m} p^\top M q = \max_{q \in \Delta_m} \min_{p \in \Delta_n} p^\top M q$$

# %% [markdown]
# #### Problem: why is the following straightforward?
# $$\min_{p \in \Delta_n} \max_{q \in \Delta_m} p^\top M q \geq \max_{q \in \Delta_m} \min_{p \in \Delta_n} p^\top M q$$
